# %%
# !pip install -q efficientnet
import pandas as pd
import numpy as np
from scipy import stats
import random
import os
import tensorflow as tf
import math
import cv2
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
import re
import tensorflow.keras.applications.efficientnet as eff
import tensorflow.keras.applications as tfka
import efficientnet.tfkeras as efn
from sklearn import metrics
import gc
from tensorflow.keras import backend as K
import tensorflow_addons as tfa
from tqdm.notebook import tqdm
from kaggle_datasets import KaggleDatasets
import tensorflow_addons as tfa

# %%
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is
    # set: this is always the case on Kaggle.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %%
# Configuration
# For tf.dataset
AUTO = tf.data.experimental.AUTOTUNE

EPOCHS = 10
BATCH_SIZE = 32 * strategy.num_replicas_in_sync
IMAGE_SIZE = [256, 256]
# Seed
SEED = 9527
seed = 9527
# Learning rate
LR = 0.0005
# Verbosity
VERBOSE = 2
# Label_dim
label_dim = 1

# dataset path
path = "../input/asthma-trigger-dataset/food_ingredients_dataset.csv"
img_path = '../input/food-ingredients-and-recipe-dataset-with-images/Food Images/Food Images/'
GCS_PATH = KaggleDatasets().get_gcs_path('asthamtest')

train_set = tf.io.gfile.glob(GCS_PATH + '/train' + '*.tfrec')
val_set = tf.io.gfile.glob(GCS_PATH + '/val' + '*.tfrec')


# common food allergens
common_allergens = {
    'cows milk': {'Cheese', 'Butter', 'Margarine', 'Yogurt', 'Cream', 'Ice cream'},
    'eggs': {'egg'},
    'tree nuts': {'Brazil nut', 'Almond', 'Cashew', 'Macadamia nut', 'Pistachio','Pine nut','Walnut'},
    'peanuts': {'peanut'},
    'shellfish': {'Shrimp','Prawn','Crayfish', 'Lobster', 'Squid', 'Scallops'},
    'wheat': {'flour', 'wheat', 'pasta', 'noodle', 'bread', 'crust'},
    'soy': {'soy', 'tofu', 'soya'},
    'fish': {'fish', 'seafood'}
}

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)
    
# Data augmentation function
def data_augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_hue(image, 0.01)
    image = tf.image.random_saturation(image, 0.70, 1.30)
    image = tf.image.random_contrast(image, 0.80, 1.20)
    image = tf.image.random_brightness(image, 0.10)
    return image, label

# Function to decode our images
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels = 3)
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image


# This function parse our images and also get the target variable
def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "cows_milk": tf.io.FixedLenFeature([], tf.int64),
        "eggs": tf.io.FixedLenFeature([], tf.int64),
        "tree nuts": tf.io.FixedLenFeature([], tf.int64),
        "peanuts": tf.io.FixedLenFeature([], tf.int64),
        "shellfish": tf.io.FixedLenFeature([], tf.int64),
        "wheat": tf.io.FixedLenFeature([], tf.int64),
        "soy": tf.io.FixedLenFeature([], tf.int64),
        "fish": tf.io.FixedLenFeature([], tf.int64),
    }

    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    
    image = decode_image(example['image'])
    milk = tf.cast(example['cows_milk'], tf.float32)
    eggs = tf.cast(example['eggs'], tf.float32)
    nuts = tf.cast(example['tree nuts'], tf.float32)
    peanuts = tf.cast(example['peanuts'], tf.float32)
    shellfish = tf.cast(example['shellfish'], tf.float32)
    wheat = tf.cast(example['wheat'], tf.float32)
    soy = tf.cast(example['soy'], tf.float32)
    fish = tf.cast(example['fish'], tf.float32)
    # label = [milk, eggs, nuts, peanuts, shellfish, wheat, soy, fish]
    label = tf.cast(example[target], tf.float32)
    return  image, label

def load_dataset(filenames, target, ordered = False):
    
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False 
        
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads = AUTO)
    dataset = dataset.with_options(ignore_order)
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls = AUTO) 
    return dataset

# This function is to get our training tensors
def get_training_dataset(filenames, target, ordered = False):
    dataset = load_dataset(filenames, target, ordered = ordered)
    dataset = dataset.map(data_augment, num_parallel_calls = AUTO)
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

# This function is to get our validation tensors
def get_validation_dataset(filenames, target, ordered = True):
    dataset = load_dataset(filenames, target, ordered = ordered)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) 
    return dataset

# Function to count how many photos we have in
def count_data_items(filenames):
    # The number of data items is written in the name of the .tfrec files, i.e. flowers00-230.tfrec = 230 data items
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

NUM_TRAINING_IMAGES = count_data_items(train_set)
print(f'Dataset: {NUM_TRAINING_IMAGES} training images')
# Out:
# Dataset: 10095 training images

# %%
# Function for a custom learning rate scheduler with warmup and decay
def get_lr_callback():
    # lr_start   = 0.0000001
    # lr_max     = 0.000005 * BATCH_SIZE
    lr_min     = 0.0000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < EPOCHS/2:
            lr = 0.000001 * (BATCH_SIZE - epoch)
        else:
            lr = lr_min
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = True)
    return lr_callback



def get_model(mode):

    with strategy.scope():

        inp = tf.keras.layers.Input(shape = (*IMAGE_SIZE, 3), name = 'inp')
        print(f'load Model_{mode}')
        if mode == 'eff0':
            x = efn.EfficientNetB0(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff1':
            x = efn.EfficientNetB1(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff2':
            x = efn.EfficientNetB2(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff3':
            x = efn.EfficientNetB3(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff4':
            x = efn.EfficientNetB4(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff5':
            x = efn.EfficientNetB5(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff6':
            x = efn.EfficientNetB6(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'eff7':
            x = efn.EfficientNetB7(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'ICPV2':
            x = tfka.InceptionResNetV2(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'ICPV3':
            x = tfka.InceptionV3(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'XCP':
            x = tfka.Xception(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'VGG16':
            x = tfka.VGG16(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'VGG19':
            x = tfka.VGG19(weights = 'imagenet', include_top = False)(inp)
        elif mode == 'RN50':
            x = tfka.ResNet50(weights = 'imagenet', include_top = False)(inp)
        else:
            # 'RN101'
            x = tfka.ResNet101(weights = 'imagenet', include_top = False)(inp)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        
        output = tf.keras.layers.Dense(label_dim, activation='sigmoid')(x)

        model = tf.keras.models.Model(inputs = [inp], outputs = [output])
        opt = tf.keras.optimizers.Adam(learning_rate = LR)

        model.compile(
            optimizer = opt,
            loss = 'BinaryCrossentropy',
            metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
            ) 
        
        return model

# %%
def image_mapping_check(dataset):
    counter = 0
    record = []
    while counter < dataset.shape[0]-1:
        row = dataset.loc[counter]
        img_name = row['Image_Name']
        img = cv2.imread(img_path+img_name+'.jpg')
        try:
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR) 
        except:
            record.append(counter)
        counter+= 1
    new = dataset.drop(record, axis = 0)
    new = new.reset_index(drop = True)
    return new

def allergens_mapping(row, types):
    for item in common_allergens[types]:
        if item.lower() in row.lower():
                return 1
    return 0

def get_weights(target):
    path = "../input/food-ingredients-and-recipe-dataset-with-images/Food Ingredients and Recipe Dataset with Image Name Mapping.csv"
    df = pd.read_csv(path)
    df = image_mapping_check(df)
    df['cows_milk'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'cows milk'))
    df['eggs'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'eggs'))
    df['tree nuts'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'tree nuts'))
    df['peanuts'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'peanuts'))
    df['shellfish'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'shellfish'))
    df['wheat'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'wheat'))
    df['soy'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'soy'))
    df['fish'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'fish'))
    x_train, x_val, y_train, y_val = train_test_split(df[['Image_Name']], df.iloc[:,6:14], shuffle = True, random_state = seed, test_size = 0.25)
    weight_0 = 1
    weight_1 = (len(y_train)-y_train[target].sum())/y_train[target].sum()

    
    class_weights = {
        0: weight_0, 
        1: weight_1
    }
    return class_weights

# %%
def train_and_evaluate(target):

    # Seed everything
    seed_everything(SEED)
    
    print('\n')
    print('-'*50)
    
    train_dataset = get_training_dataset(train_set, target, ordered = False)
    val_dataset = get_validation_dataset(val_set, target, ordered = True)
    STEPS_PER_EPOCH = count_data_items(train_set) // BATCH_SIZE
    K.clear_session()
    model = get_model(mode)
    # Model checkpoint
    checkpoint = tf.keras.callbacks.ModelCheckpoint(f'Model_{mode}_{target}_{SEED}.h5', 
                                                    monitor = 'val_loss', 
                                                    verbose = VERBOSE, 
                                                    save_best_only = True,
                                                    save_weights_only = True, 
                                                    mode = 'min')

    class_weight = get_weights(target)
    
    history = model.fit(train_dataset,
                        steps_per_epoch = STEPS_PER_EPOCH,
                        class_weight=class_weight,
                        epochs = EPOCHS,
                        callbacks = [checkpoint, get_lr_callback()], 
                        validation_data = val_dataset,
                        verbose = VERBOSE)
    gc.collect()

# %%
models = ['eff0','eff1','eff2','eff3','eff4','eff5','eff6','eff7','ICPV2','ICPV3', 'XCP', 'RN50', 'RN101']
# targets = ["cows_milk", "eggs", "tree nuts", "peanuts", "shellfish", "wheat", "soy", "fish"]
targets = ["shellfish", "wheat", "soy", "fish"]
for target in targets:
    for mode in models:
        print('prediction target is', target)
        train_and_evaluate(target)
# Out:
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff0
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 0s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 63s - loss: 1.2343 - accuracy: 0.5901 - precision: 0.0620 - recall: 0.6939 - val_loss: 0.6861 - val_accuracy: 0.5660 - val_precision: 0.0745 - val_recall: 0.8529
#
# Epoch 00001: val_loss improved from inf to 0.68610, saving model to Model_eff0_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 6s - loss: 0.9038 - accuracy: 0.7252 - precision: 0.1013 - recall: 0.8229 - val_loss: 0.5470 - val_accuracy: 0.7103 - val_precision: 0.1039 - val_recall: 0.8088
#
# Epoch 00002: val_loss improved from 0.68610 to 0.54696, saving model to Model_eff0_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 6s - loss: 0.6713 - accuracy: 0.8202 - precision: 0.1555 - recall: 0.8750 - val_loss: 0.3877 - val_accuracy: 0.8167 - val_precision: 0.1383 - val_recall: 0.6765
#
# Epoch 00003: val_loss improved from 0.54696 to 0.38772, saving model to Model_eff0_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 7s - loss: 0.5414 - accuracy: 0.8603 - precision: 0.2009 - recall: 0.9072 - val_loss: 0.3031 - val_accuracy: 0.8672 - val_precision: 0.1521 - val_recall: 0.5000
#
# Epoch 00004: val_loss improved from 0.38772 to 0.30309, saving model to Model_eff0_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 6s - loss: 0.4361 - accuracy: 0.9012 - precision: 0.2640 - recall: 0.9272 - val_loss: 0.1843 - val_accuracy: 0.9329 - val_precision: 0.2472 - val_recall: 0.3235
#
# Epoch 00005: val_loss improved from 0.30309 to 0.18426, saving model to Model_eff0_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 6s - loss: 0.3692 - accuracy: 0.9090 - precision: 0.2866 - recall: 0.9521 - val_loss: 0.2081 - val_accuracy: 0.9210 - val_precision: 0.2336 - val_recall: 0.4191
#
# Epoch 00006: val_loss did not improve from 0.18426
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 6s - loss: 0.3465 - accuracy: 0.9129 - precision: 0.2923 - recall: 0.9646 - val_loss: 0.2325 - val_accuracy: 0.9070 - val_precision: 0.2136 - val_recall: 0.4853
#
# Epoch 00007: val_loss did not improve from 0.18426
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 6s - loss: 0.3681 - accuracy: 0.9085 - precision: 0.2842 - recall: 0.9597 - val_loss: 0.2535 - val_accuracy: 0.8981 - val_precision: 0.2051 - val_recall: 0.5294
#
# Epoch 00008: val_loss did not improve from 0.18426
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.3434 - accuracy: 0.9118 - precision: 0.2921 - recall: 0.9571 - val_loss: 0.2691 - val_accuracy: 0.8886 - val_precision: 0.1912 - val_recall: 0.5441
#
# Epoch 00009: val_loss did not improve from 0.18426
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 6s - loss: 0.3706 - accuracy: 0.9108 - precision: 0.2931 - recall: 0.9526 - val_loss: 0.2788 - val_accuracy: 0.8847 - val_precision: 0.1927 - val_recall: 0.5809
#
# Epoch 00010: val_loss did not improve from 0.18426
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff1
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b1_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 27164672/27164032 [==============================] - 0s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 85s - loss: 1.1921 - accuracy: 0.5749 - precision: 0.0636 - recall: 0.7520 - val_loss: 0.5949 - val_accuracy: 0.6655 - val_precision: 0.0847 - val_recall: 0.7426
#
# Epoch 00001: val_loss improved from inf to 0.59488, saving model to Model_eff1_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 8s - loss: 0.8907 - accuracy: 0.7675 - precision: 0.1164 - recall: 0.8000 - val_loss: 0.4866 - val_accuracy: 0.7662 - val_precision: 0.1166 - val_recall: 0.7279
#
# Epoch 00002: val_loss improved from 0.59488 to 0.48655, saving model to Model_eff1_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 8s - loss: 0.6716 - accuracy: 0.8342 - precision: 0.1691 - recall: 0.8720 - val_loss: 0.2929 - val_accuracy: 0.8740 - val_precision: 0.1588 - val_recall: 0.4926
#
# Epoch 00003: val_loss improved from 0.48655 to 0.29292, saving model to Model_eff1_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 8s - loss: 0.5173 - accuracy: 0.8663 - precision: 0.2048 - recall: 0.9180 - val_loss: 0.2510 - val_accuracy: 0.9034 - val_precision: 0.1981 - val_recall: 0.4559
#
# Epoch 00004: val_loss improved from 0.29292 to 0.25098, saving model to Model_eff1_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 8s - loss: 0.4998 - accuracy: 0.8829 - precision: 0.2272 - recall: 0.9101 - val_loss: 0.1735 - val_accuracy: 0.9456 - val_precision: 0.3233 - val_recall: 0.3162
#
# Epoch 00005: val_loss improved from 0.25098 to 0.17351, saving model to Model_eff1_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3595 - accuracy: 0.9174 - precision: 0.3062 - recall: 0.9624 - val_loss: 0.1886 - val_accuracy: 0.9326 - val_precision: 0.2690 - val_recall: 0.3897
#
# Epoch 00006: val_loss did not improve from 0.17351
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3538 - accuracy: 0.9117 - precision: 0.2868 - recall: 0.9614 - val_loss: 0.2056 - val_accuracy: 0.9222 - val_precision: 0.2375 - val_recall: 0.4191
#
# Epoch 00007: val_loss did not improve from 0.17351
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3905 - accuracy: 0.9088 - precision: 0.2896 - recall: 0.9403 - val_loss: 0.2197 - val_accuracy: 0.9144 - val_precision: 0.2226 - val_recall: 0.4485
#
# Epoch 00008: val_loss did not improve from 0.17351
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3728 - accuracy: 0.9126 - precision: 0.2963 - recall: 0.9524 - val_loss: 0.2320 - val_accuracy: 0.9088 - val_precision: 0.2178 - val_recall: 0.4853
#
# Epoch 00009: val_loss did not improve from 0.17351
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3574 - accuracy: 0.9127 - precision: 0.2929 - recall: 0.9595 - val_loss: 0.2415 - val_accuracy: 0.9067 - val_precision: 0.2201 - val_recall: 0.5147
#
# Epoch 00010: val_loss did not improve from 0.17351
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff2
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b2_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 31940608/31936256 [==============================] - 1s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 87s - loss: 1.1825 - accuracy: 0.5893 - precision: 0.0605 - recall: 0.6984 - val_loss: 0.8178 - val_accuracy: 0.5312 - val_precision: 0.0729 - val_recall: 0.9044
#
# Epoch 00001: val_loss improved from inf to 0.81777, saving model to Model_eff2_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 8s - loss: 0.8971 - accuracy: 0.7713 - precision: 0.1221 - recall: 0.8037 - val_loss: 0.7177 - val_accuracy: 0.6289 - val_precision: 0.0856 - val_recall: 0.8456
#
# Epoch 00002: val_loss improved from 0.81777 to 0.71771, saving model to Model_eff2_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 8s - loss: 0.6626 - accuracy: 0.8348 - precision: 0.1686 - recall: 0.8760 - val_loss: 0.3823 - val_accuracy: 0.8286 - val_precision: 0.1461 - val_recall: 0.6691
#
# Epoch 00003: val_loss improved from 0.71771 to 0.38232, saving model to Model_eff2_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 9s - loss: 0.5620 - accuracy: 0.8634 - precision: 0.2013 - recall: 0.9054 - val_loss: 0.3737 - val_accuracy: 0.8411 - val_precision: 0.1506 - val_recall: 0.6324
#
# Epoch 00004: val_loss improved from 0.38232 to 0.37369, saving model to Model_eff2_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 8s - loss: 0.4003 - accuracy: 0.9018 - precision: 0.2683 - recall: 0.9385 - val_loss: 0.2172 - val_accuracy: 0.9201 - val_precision: 0.2146 - val_recall: 0.3676
#
# Epoch 00005: val_loss improved from 0.37369 to 0.21721, saving model to Model_eff2_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3062 - accuracy: 0.9379 - precision: 0.3639 - recall: 0.9530 - val_loss: 0.2251 - val_accuracy: 0.9177 - val_precision: 0.2235 - val_recall: 0.4191
#
# Epoch 00006: val_loss did not improve from 0.21721
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3266 - accuracy: 0.9392 - precision: 0.3838 - recall: 0.9456 - val_loss: 0.2294 - val_accuracy: 0.9130 - val_precision: 0.2125 - val_recall: 0.4265
#
# Epoch 00007: val_loss did not improve from 0.21721
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3378 - accuracy: 0.9367 - precision: 0.3596 - recall: 0.9370 - val_loss: 0.2341 - val_accuracy: 0.9076 - val_precision: 0.2074 - val_recall: 0.4559
#
# Epoch 00008: val_loss did not improve from 0.21721
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3208 - accuracy: 0.9368 - precision: 0.3691 - recall: 0.9496 - val_loss: 0.2377 - val_accuracy: 0.9043 - val_precision: 0.2057 - val_recall: 0.4779
#
# Epoch 00009: val_loss did not improve from 0.21721
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3171 - accuracy: 0.9405 - precision: 0.3785 - recall: 0.9565 - val_loss: 0.2403 - val_accuracy: 0.9031 - val_precision: 0.2086 - val_recall: 0.5000
#
# Epoch 00010: val_loss did not improve from 0.21721
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff3
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 44113920/44107200 [==============================] - 0s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 97s - loss: 1.2349 - accuracy: 0.5832 - precision: 0.0603 - recall: 0.6762 - val_loss: 0.5310 - val_accuracy: 0.7279 - val_precision: 0.1100 - val_recall: 0.8088
#
# Epoch 00001: val_loss improved from inf to 0.53104, saving model to Model_eff3_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 9s - loss: 0.8947 - accuracy: 0.7481 - precision: 0.1103 - recall: 0.8123 - val_loss: 0.3223 - val_accuracy: 0.8630 - val_precision: 0.1717 - val_recall: 0.6250
#
# Epoch 00002: val_loss improved from 0.53104 to 0.32228, saving model to Model_eff3_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 9s - loss: 0.6602 - accuracy: 0.8282 - precision: 0.1533 - recall: 0.8527 - val_loss: 0.1739 - val_accuracy: 0.9430 - val_precision: 0.2812 - val_recall: 0.2647
#
# Epoch 00003: val_loss improved from 0.32228 to 0.17388, saving model to Model_eff3_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 9s - loss: 0.5195 - accuracy: 0.8701 - precision: 0.2098 - recall: 0.8954 - val_loss: 0.1767 - val_accuracy: 0.9418 - val_precision: 0.2826 - val_recall: 0.2868
#
# Epoch 00004: val_loss did not improve from 0.17388
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 9s - loss: 0.4061 - accuracy: 0.9089 - precision: 0.2799 - recall: 0.9322 - val_loss: 0.2002 - val_accuracy: 0.9343 - val_precision: 0.2599 - val_recall: 0.3382
#
# Epoch 00005: val_loss did not improve from 0.17388
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 9s - loss: 0.3568 - accuracy: 0.9231 - precision: 0.3236 - recall: 0.9318 - val_loss: 0.2192 - val_accuracy: 0.9216 - val_precision: 0.2355 - val_recall: 0.4191
#
# Epoch 00006: val_loss did not improve from 0.17388
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 9s - loss: 0.3412 - accuracy: 0.9257 - precision: 0.3327 - recall: 0.9423 - val_loss: 0.2348 - val_accuracy: 0.9112 - val_precision: 0.2100 - val_recall: 0.4338
#
# Epoch 00007: val_loss did not improve from 0.17388
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 9s - loss: 0.3655 - accuracy: 0.9264 - precision: 0.3327 - recall: 0.9239 - val_loss: 0.2470 - val_accuracy: 0.9052 - val_precision: 0.2132 - val_recall: 0.5000
#
# Epoch 00008: val_loss did not improve from 0.17388
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 9s - loss: 0.3787 - accuracy: 0.9261 - precision: 0.3215 - recall: 0.9205 - val_loss: 0.2564 - val_accuracy: 0.8993 - val_precision: 0.1988 - val_recall: 0.4926
#
# Epoch 00009: val_loss did not improve from 0.17388
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 9s - loss: 0.3273 - accuracy: 0.9266 - precision: 0.3264 - recall: 0.9479 - val_loss: 0.2657 - val_accuracy: 0.8948 - val_precision: 0.1972 - val_recall: 0.5221
#
# Epoch 00010: val_loss did not improve from 0.17388
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff4
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b4_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 71892992/71892840 [==============================] - 1s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 119s - loss: 1.2374 - accuracy: 0.5662 - precision: 0.0565 - recall: 0.6738 - val_loss: 0.7338 - val_accuracy: 0.5294 - val_precision: 0.0736 - val_recall: 0.9191
#
# Epoch 00001: val_loss improved from inf to 0.73385, saving model to Model_eff4_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 11s - loss: 0.8755 - accuracy: 0.7515 - precision: 0.1167 - recall: 0.8443 - val_loss: 0.6091 - val_accuracy: 0.6878 - val_precision: 0.0969 - val_recall: 0.8088
#
# Epoch 00002: val_loss improved from 0.73385 to 0.60914, saving model to Model_eff4_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 11s - loss: 0.6976 - accuracy: 0.8179 - precision: 0.1526 - recall: 0.8740 - val_loss: 0.3575 - val_accuracy: 0.8387 - val_precision: 0.1449 - val_recall: 0.6103
#
# Epoch 00003: val_loss improved from 0.60914 to 0.35745, saving model to Model_eff4_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 11s - loss: 0.5421 - accuracy: 0.8699 - precision: 0.2063 - recall: 0.8886 - val_loss: 0.2735 - val_accuracy: 0.8904 - val_precision: 0.2005 - val_recall: 0.5735
#
# Epoch 00004: val_loss improved from 0.35745 to 0.27352, saving model to Model_eff4_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 11s - loss: 0.4121 - accuracy: 0.8983 - precision: 0.2619 - recall: 0.9387 - val_loss: 0.2704 - val_accuracy: 0.9011 - val_precision: 0.2060 - val_recall: 0.5074
#
# Epoch 00005: val_loss improved from 0.27352 to 0.27040, saving model to Model_eff4_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3884 - accuracy: 0.8959 - precision: 0.2551 - recall: 0.9616 - val_loss: 0.2964 - val_accuracy: 0.8874 - val_precision: 0.1908 - val_recall: 0.5515
#
# Epoch 00006: val_loss did not improve from 0.27040
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3679 - accuracy: 0.9012 - precision: 0.2676 - recall: 0.9542 - val_loss: 0.3159 - val_accuracy: 0.8770 - val_precision: 0.1797 - val_recall: 0.5735
#
# Epoch 00007: val_loss did not improve from 0.27040
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3617 - accuracy: 0.9006 - precision: 0.2732 - recall: 0.9659 - val_loss: 0.3328 - val_accuracy: 0.8705 - val_precision: 0.1725 - val_recall: 0.5809
#
# Epoch 00008: val_loss did not improve from 0.27040
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3512 - accuracy: 0.9008 - precision: 0.2651 - recall: 0.9617 - val_loss: 0.3478 - val_accuracy: 0.8619 - val_precision: 0.1622 - val_recall: 0.5809
#
# Epoch 00009: val_loss did not improve from 0.27040
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3431 - accuracy: 0.9033 - precision: 0.2791 - recall: 0.9685 - val_loss: 0.3567 - val_accuracy: 0.8577 - val_precision: 0.1590 - val_recall: 0.5882
#
# Epoch 00010: val_loss did not improve from 0.27040
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff5
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b5_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 115515392/115515256 [==============================] - 2s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 150s - loss: 1.2711 - accuracy: 0.5666 - precision: 0.0542 - recall: 0.6383 - val_loss: 0.6398 - val_accuracy: 0.6016 - val_precision: 0.0796 - val_recall: 0.8382
#
# Epoch 00001: val_loss improved from inf to 0.63978, saving model to Model_eff5_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 13s - loss: 0.9537 - accuracy: 0.7145 - precision: 0.0943 - recall: 0.7961 - val_loss: 0.5432 - val_accuracy: 0.7282 - val_precision: 0.1038 - val_recall: 0.7500
#
# Epoch 00002: val_loss improved from 0.63978 to 0.54317, saving model to Model_eff5_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 13s - loss: 0.8304 - accuracy: 0.7911 - precision: 0.1364 - recall: 0.8264 - val_loss: 0.3963 - val_accuracy: 0.8182 - val_precision: 0.1270 - val_recall: 0.5956
#
# Epoch 00003: val_loss improved from 0.54317 to 0.39635, saving model to Model_eff5_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 13s - loss: 0.6234 - accuracy: 0.8327 - precision: 0.1659 - recall: 0.8877 - val_loss: 0.3111 - val_accuracy: 0.8645 - val_precision: 0.1639 - val_recall: 0.5735
#
# Epoch 00004: val_loss improved from 0.39635 to 0.31105, saving model to Model_eff5_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 13s - loss: 0.5209 - accuracy: 0.8876 - precision: 0.2369 - recall: 0.9264 - val_loss: 0.2121 - val_accuracy: 0.9367 - val_precision: 0.2484 - val_recall: 0.2794
#
# Epoch 00005: val_loss improved from 0.31105 to 0.21213, saving model to Model_eff5_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 13s - loss: 0.4289 - accuracy: 0.9107 - precision: 0.2858 - recall: 0.9328 - val_loss: 0.2173 - val_accuracy: 0.9329 - val_precision: 0.2527 - val_recall: 0.3382
#
# Epoch 00006: val_loss did not improve from 0.21213
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 13s - loss: 0.4194 - accuracy: 0.9168 - precision: 0.3063 - recall: 0.9293 - val_loss: 0.2222 - val_accuracy: 0.9266 - val_precision: 0.2344 - val_recall: 0.3603
#
# Epoch 00007: val_loss did not improve from 0.21213
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 13s - loss: 0.4479 - accuracy: 0.9115 - precision: 0.2817 - recall: 0.9049 - val_loss: 0.2262 - val_accuracy: 0.9228 - val_precision: 0.2281 - val_recall: 0.3824
#
# Epoch 00008: val_loss did not improve from 0.21213
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 13s - loss: 0.3970 - accuracy: 0.9104 - precision: 0.2790 - recall: 0.9126 - val_loss: 0.2318 - val_accuracy: 0.9189 - val_precision: 0.2227 - val_recall: 0.4044
#
# Epoch 00009: val_loss did not improve from 0.21213
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 13s - loss: 0.4165 - accuracy: 0.9093 - precision: 0.2855 - recall: 0.9211 - val_loss: 0.2356 - val_accuracy: 0.9165 - val_precision: 0.2179 - val_recall: 0.4118
#
# Epoch 00010: val_loss did not improve from 0.21213
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff6
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b6_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 165527552/165527152 [==============================] - 3s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 176s - loss: 1.2442 - accuracy: 0.5642 - precision: 0.0578 - recall: 0.6933 - val_loss: 0.7078 - val_accuracy: 0.5570 - val_precision: 0.0768 - val_recall: 0.9044
#
# Epoch 00001: val_loss improved from inf to 0.70781, saving model to Model_eff6_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 15s - loss: 1.0035 - accuracy: 0.6707 - precision: 0.0871 - recall: 0.8392 - val_loss: 0.3834 - val_accuracy: 0.8336 - val_precision: 0.1382 - val_recall: 0.5956
#
# Epoch 00002: val_loss improved from 0.70781 to 0.38342, saving model to Model_eff6_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 15s - loss: 0.8201 - accuracy: 0.7751 - precision: 0.1292 - recall: 0.8553 - val_loss: 0.2436 - val_accuracy: 0.8966 - val_precision: 0.1919 - val_recall: 0.4853
#
# Epoch 00003: val_loss improved from 0.38342 to 0.24362, saving model to Model_eff6_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 15s - loss: 0.6830 - accuracy: 0.8182 - precision: 0.1571 - recall: 0.8824 - val_loss: 0.5639 - val_accuracy: 0.7519 - val_precision: 0.1172 - val_recall: 0.7868
#
# Epoch 00004: val_loss did not improve from 0.24362
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 15s - loss: 0.5306 - accuracy: 0.8666 - precision: 0.1999 - recall: 0.8923 - val_loss: 0.2559 - val_accuracy: 0.8945 - val_precision: 0.1967 - val_recall: 0.5221
#
# Epoch 00005: val_loss did not improve from 0.24362
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 15s - loss: 0.4780 - accuracy: 0.8803 - precision: 0.2285 - recall: 0.9200 - val_loss: 0.2802 - val_accuracy: 0.8835 - val_precision: 0.1878 - val_recall: 0.5662
#
# Epoch 00006: val_loss did not improve from 0.24362
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 15s - loss: 0.4907 - accuracy: 0.8802 - precision: 0.2302 - recall: 0.9233 - val_loss: 0.2938 - val_accuracy: 0.8794 - val_precision: 0.1846 - val_recall: 0.5809
#
# Epoch 00007: val_loss did not improve from 0.24362
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 15s - loss: 0.4523 - accuracy: 0.8854 - precision: 0.2328 - recall: 0.9262 - val_loss: 0.3014 - val_accuracy: 0.8755 - val_precision: 0.1777 - val_recall: 0.5735
#
# Epoch 00008: val_loss did not improve from 0.24362
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 15s - loss: 0.4644 - accuracy: 0.8832 - precision: 0.2347 - recall: 0.9257 - val_loss: 0.3068 - val_accuracy: 0.8690 - val_precision: 0.1706 - val_recall: 0.5809
#
# Epoch 00009: val_loss did not improve from 0.24362
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 15s - loss: 0.4539 - accuracy: 0.8839 - precision: 0.2331 - recall: 0.9350 - val_loss: 0.3099 - val_accuracy: 0.8687 - val_precision: 0.1703 - val_recall: 0.5809
#
# Epoch 00010: val_loss did not improve from 0.24362
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_eff7
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258441216/258434480 [==============================] - 4s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 220s - loss: 1.2712 - accuracy: 0.5309 - precision: 0.0541 - recall: 0.6797 - val_loss: 0.5392 - val_accuracy: 0.7160 - val_precision: 0.0933 - val_recall: 0.6912
#
# Epoch 00001: val_loss improved from inf to 0.53917, saving model to Model_eff7_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 20s - loss: 1.0590 - accuracy: 0.6739 - precision: 0.0810 - recall: 0.7799 - val_loss: 0.4296 - val_accuracy: 0.7947 - val_precision: 0.1224 - val_recall: 0.6618
#
# Epoch 00002: val_loss improved from 0.53917 to 0.42955, saving model to Model_eff7_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 20s - loss: 0.9155 - accuracy: 0.7284 - precision: 0.1034 - recall: 0.8199 - val_loss: 0.5243 - val_accuracy: 0.7496 - val_precision: 0.1111 - val_recall: 0.7426
#
# Epoch 00003: val_loss did not improve from 0.42955
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 20s - loss: 0.7570 - accuracy: 0.8105 - precision: 0.1447 - recall: 0.8262 - val_loss: 0.2390 - val_accuracy: 0.9124 - val_precision: 0.2211 - val_recall: 0.4632
#
# Epoch 00004: val_loss improved from 0.42955 to 0.23898, saving model to Model_eff7_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 20s - loss: 0.6545 - accuracy: 0.8405 - precision: 0.1759 - recall: 0.8997 - val_loss: 0.3216 - val_accuracy: 0.8610 - val_precision: 0.1598 - val_recall: 0.5735
#
# Epoch 00005: val_loss did not improve from 0.23898
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 20s - loss: 0.4895 - accuracy: 0.8598 - precision: 0.2056 - recall: 0.9547 - val_loss: 0.3244 - val_accuracy: 0.8556 - val_precision: 0.1555 - val_recall: 0.5809
#
# Epoch 00006: val_loss did not improve from 0.23898
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 20s - loss: 0.5132 - accuracy: 0.8623 - precision: 0.2062 - recall: 0.9462 - val_loss: 0.3270 - val_accuracy: 0.8604 - val_precision: 0.1660 - val_recall: 0.6103
#
# Epoch 00007: val_loss did not improve from 0.23898
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 20s - loss: 0.5246 - accuracy: 0.8554 - precision: 0.1929 - recall: 0.9288 - val_loss: 0.3300 - val_accuracy: 0.8583 - val_precision: 0.1637 - val_recall: 0.6103
#
# Epoch 00008: val_loss did not improve from 0.23898
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 21s - loss: 0.5064 - accuracy: 0.8643 - precision: 0.2124 - recall: 0.9373 - val_loss: 0.3288 - val_accuracy: 0.8601 - val_precision: 0.1657 - val_recall: 0.6103
#
# Epoch 00009: val_loss did not improve from 0.23898
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 20s - loss: 0.5069 - accuracy: 0.8590 - precision: 0.1987 - recall: 0.9425 - val_loss: 0.3296 - val_accuracy: 0.8595 - val_precision: 0.1650 - val_recall: 0.6103
#
# Epoch 00010: val_loss did not improve from 0.23898
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_ICPV2
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 184s - loss: 1.2568 - accuracy: 0.6061 - precision: 0.0608 - recall: 0.6823 - val_loss: 0.2006 - val_accuracy: 0.9450 - val_precision: 0.1818 - val_recall: 0.1029
#
# Epoch 00001: val_loss improved from inf to 0.20064, saving model to Model_ICPV2_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 11s - loss: 0.9735 - accuracy: 0.7161 - precision: 0.1007 - recall: 0.8089 - val_loss: 0.3829 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 0.20064
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 11s - loss: 0.7722 - accuracy: 0.7912 - precision: 0.1353 - recall: 0.8571 - val_loss: 0.5709 - val_accuracy: 0.9299 - val_precision: 0.0192 - val_recall: 0.0147
#
# Epoch 00003: val_loss did not improve from 0.20064
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 11s - loss: 0.6217 - accuracy: 0.8402 - precision: 0.1787 - recall: 0.8895 - val_loss: 0.7549 - val_accuracy: 0.4302 - val_precision: 0.0445 - val_recall: 0.6397
#
# Epoch 00004: val_loss did not improve from 0.20064
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 11s - loss: 0.5120 - accuracy: 0.8682 - precision: 0.2057 - recall: 0.9071 - val_loss: 0.3049 - val_accuracy: 0.9593 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.20064
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3783 - accuracy: 0.8842 - precision: 0.2335 - recall: 0.9454 - val_loss: 0.2366 - val_accuracy: 0.9542 - val_precision: 0.3500 - val_recall: 0.1544
#
# Epoch 00006: val_loss did not improve from 0.20064
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3901 - accuracy: 0.8847 - precision: 0.2384 - recall: 0.9388 - val_loss: 0.2187 - val_accuracy: 0.9382 - val_precision: 0.2722 - val_recall: 0.3162
#
# Epoch 00007: val_loss did not improve from 0.20064
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3821 - accuracy: 0.8862 - precision: 0.2395 - recall: 0.9592 - val_loss: 0.2376 - val_accuracy: 0.9216 - val_precision: 0.2355 - val_recall: 0.4191
#
# Epoch 00008: val_loss did not improve from 0.20064
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3845 - accuracy: 0.8910 - precision: 0.2547 - recall: 0.9556 - val_loss: 0.2646 - val_accuracy: 0.9005 - val_precision: 0.1920 - val_recall: 0.4559
#
# Epoch 00009: val_loss did not improve from 0.20064
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.3679 - accuracy: 0.8881 - precision: 0.2415 - recall: 0.9511 - val_loss: 0.2881 - val_accuracy: 0.8877 - val_precision: 0.1765 - val_recall: 0.4853
#
# Epoch 00010: val_loss did not improve from 0.20064
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_ICPV3
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 90s - loss: 1.2684 - accuracy: 0.5926 - precision: 0.0575 - recall: 0.6452 - val_loss: 0.2747 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.27466, saving model to Model_ICPV3_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 8s - loss: 0.9581 - accuracy: 0.7289 - precision: 0.1026 - recall: 0.8027 - val_loss: 0.4801 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 0.27466
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 8s - loss: 0.7864 - accuracy: 0.7915 - precision: 0.1281 - recall: 0.8154 - val_loss: 0.2355 - val_accuracy: 0.9551 - val_precision: 0.1053 - val_recall: 0.0147
#
# Epoch 00003: val_loss improved from 0.27466 to 0.23551, saving model to Model_ICPV3_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 7s - loss: 0.6948 - accuracy: 0.8124 - precision: 0.1543 - recall: 0.8859 - val_loss: 0.2039 - val_accuracy: 0.9299 - val_precision: 0.1914 - val_recall: 0.2279
#
# Epoch 00004: val_loss improved from 0.23551 to 0.20394, saving model to Model_ICPV3_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 7s - loss: 0.5668 - accuracy: 0.8574 - precision: 0.1937 - recall: 0.8976 - val_loss: 0.1810 - val_accuracy: 0.9462 - val_precision: 0.2414 - val_recall: 0.1544
#
# Epoch 00005: val_loss improved from 0.20394 to 0.18095, saving model to Model_ICPV3_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5229 - accuracy: 0.9274 - precision: 0.3212 - recall: 0.8522 - val_loss: 0.1965 - val_accuracy: 0.9290 - val_precision: 0.2090 - val_recall: 0.2721
#
# Epoch 00006: val_loss did not improve from 0.18095
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5249 - accuracy: 0.9310 - precision: 0.3433 - recall: 0.8649 - val_loss: 0.2166 - val_accuracy: 0.9189 - val_precision: 0.1956 - val_recall: 0.3235
#
# Epoch 00007: val_loss did not improve from 0.18095
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.4824 - accuracy: 0.9278 - precision: 0.3220 - recall: 0.8770 - val_loss: 0.2317 - val_accuracy: 0.9103 - val_precision: 0.1926 - val_recall: 0.3824
#
# Epoch 00008: val_loss did not improve from 0.18095
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.4733 - accuracy: 0.9326 - precision: 0.3362 - recall: 0.8658 - val_loss: 0.2422 - val_accuracy: 0.9029 - val_precision: 0.1763 - val_recall: 0.3824
#
# Epoch 00009: val_loss did not improve from 0.18095
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.4624 - accuracy: 0.9321 - precision: 0.3453 - recall: 0.8912 - val_loss: 0.2485 - val_accuracy: 0.8978 - val_precision: 0.1667 - val_recall: 0.3824
#
# Epoch 00010: val_loss did not improve from 0.18095
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_XCP
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 62s - loss: 1.1962 - accuracy: 0.6664 - precision: 0.0693 - recall: 0.6347 - val_loss: 0.2905 - val_accuracy: 0.8622 - val_precision: 0.1388 - val_recall: 0.4632
#
# Epoch 00001: val_loss improved from inf to 0.29052, saving model to Model_XCP_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 8s - loss: 0.8464 - accuracy: 0.7698 - precision: 0.1230 - recall: 0.8396 - val_loss: 0.2166 - val_accuracy: 0.9596 - val_precision: 0.5000 - val_recall: 0.0221
#
# Epoch 00002: val_loss improved from 0.29052 to 0.21665, saving model to Model_XCP_shellfish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 8s - loss: 0.6603 - accuracy: 0.8465 - precision: 0.1769 - recall: 0.8668 - val_loss: 0.2138 - val_accuracy: 0.9590 - val_precision: 0.2500 - val_recall: 0.0074
#
# Epoch 00003: val_loss improved from 0.21665 to 0.21382, saving model to Model_XCP_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 8s - loss: 0.4667 - accuracy: 0.8957 - precision: 0.2539 - recall: 0.9048 - val_loss: 0.2271 - val_accuracy: 0.9575 - val_precision: 0.2308 - val_recall: 0.0221
#
# Epoch 00004: val_loss did not improve from 0.21382
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 8s - loss: 0.4072 - accuracy: 0.9180 - precision: 0.2946 - recall: 0.9192 - val_loss: 0.2188 - val_accuracy: 0.9566 - val_precision: 0.3529 - val_recall: 0.0882
#
# Epoch 00005: val_loss did not improve from 0.21382
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3601 - accuracy: 0.9317 - precision: 0.3428 - recall: 0.9137 - val_loss: 0.1793 - val_accuracy: 0.9542 - val_precision: 0.3929 - val_recall: 0.2426
#
# Epoch 00006: val_loss improved from 0.21382 to 0.17932, saving model to Model_XCP_shellfish_9527.h5
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3209 - accuracy: 0.9371 - precision: 0.3624 - recall: 0.9426 - val_loss: 0.1815 - val_accuracy: 0.9424 - val_precision: 0.3092 - val_recall: 0.3456
#
# Epoch 00007: val_loss did not improve from 0.17932
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3470 - accuracy: 0.9318 - precision: 0.3605 - recall: 0.9416 - val_loss: 0.1997 - val_accuracy: 0.9320 - val_precision: 0.2709 - val_recall: 0.4044
#
# Epoch 00008: val_loss did not improve from 0.17932
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3339 - accuracy: 0.9337 - precision: 0.3437 - recall: 0.9276 - val_loss: 0.2217 - val_accuracy: 0.9207 - val_precision: 0.2431 - val_recall: 0.4559
#
# Epoch 00009: val_loss did not improve from 0.17932
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.2962 - accuracy: 0.9332 - precision: 0.3470 - recall: 0.9558 - val_loss: 0.2400 - val_accuracy: 0.9067 - val_precision: 0.2129 - val_recall: 0.4853
#
# Epoch 00010: val_loss did not improve from 0.17932
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_RN50
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 68s - loss: 1.3222 - accuracy: 0.6353 - precision: 0.0686 - recall: 0.6989 - val_loss: 0.4707 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.47075, saving model to Model_RN50_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 7s - loss: 1.0970 - accuracy: 0.7243 - precision: 0.0963 - recall: 0.7808 - val_loss: 1.4679 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 0.47075
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 7s - loss: 0.9757 - accuracy: 0.7721 - precision: 0.1200 - recall: 0.7827 - val_loss: 0.3184 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss improved from 0.47075 to 0.31839, saving model to Model_RN50_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 7s - loss: 0.7453 - accuracy: 0.8279 - precision: 0.1569 - recall: 0.8564 - val_loss: 0.1830 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss improved from 0.31839 to 0.18299, saving model to Model_RN50_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 8s - loss: 0.6597 - accuracy: 0.8400 - precision: 0.1792 - recall: 0.8641 - val_loss: 0.3367 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.18299
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5616 - accuracy: 0.8883 - precision: 0.2271 - recall: 0.8799 - val_loss: 0.4365 - val_accuracy: 0.9596 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 0.18299
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5244 - accuracy: 0.8940 - precision: 0.2482 - recall: 0.9086 - val_loss: 0.5609 - val_accuracy: 0.8859 - val_precision: 0.0407 - val_recall: 0.0809
#
# Epoch 00007: val_loss did not improve from 0.18299
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5382 - accuracy: 0.8857 - precision: 0.2362 - recall: 0.8828 - val_loss: 0.7123 - val_accuracy: 0.5083 - val_precision: 0.0455 - val_recall: 0.5588
#
# Epoch 00008: val_loss did not improve from 0.18299
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5124 - accuracy: 0.8892 - precision: 0.2323 - recall: 0.8846 - val_loss: 0.8816 - val_accuracy: 0.2219 - val_precision: 0.0421 - val_recall: 0.8382
#
# Epoch 00009: val_loss did not improve from 0.18299
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5204 - accuracy: 0.8884 - precision: 0.2387 - recall: 0.8963 - val_loss: 1.0216 - val_accuracy: 0.1150 - val_precision: 0.0416 - val_recall: 0.9485
#
# Epoch 00010: val_loss did not improve from 0.18299
# prediction target is shellfish
#
#
# --------------------------------------------------
# load Model_RN101
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 1s 0us/step
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 111s - loss: 1.4691 - accuracy: 0.6013 - precision: 0.0627 - recall: 0.6736 - val_loss: 2.3714 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00001: val_loss improved from inf to 2.37137, saving model to Model_RN101_shellfish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 10s - loss: 1.4141 - accuracy: 0.6921 - precision: 0.0755 - recall: 0.6603 - val_loss: 13.7571 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00002: val_loss did not improve from 2.37137
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 10s - loss: 1.0594 - accuracy: 0.7424 - precision: 0.0970 - recall: 0.7182 - val_loss: 1.4783 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00003: val_loss improved from 2.37137 to 1.47831, saving model to Model_RN101_shellfish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 10s - loss: 0.9112 - accuracy: 0.7697 - precision: 0.1186 - recall: 0.7952 - val_loss: 1.0544 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00004: val_loss improved from 1.47831 to 1.05444, saving model to Model_RN101_shellfish_9527.h5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 10s - loss: 0.7447 - accuracy: 0.8210 - precision: 0.1494 - recall: 0.8567 - val_loss: 0.8208 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00005: val_loss improved from 1.05444 to 0.82080, saving model to Model_RN101_shellfish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.6764 - accuracy: 0.8241 - precision: 0.1638 - recall: 0.8793 - val_loss: 1.1082 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00006: val_loss did not improve from 0.82080
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.6627 - accuracy: 0.8197 - precision: 0.1590 - recall: 0.8830 - val_loss: 1.2847 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00007: val_loss did not improve from 0.82080
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.6478 - accuracy: 0.8243 - precision: 0.1609 - recall: 0.8841 - val_loss: 1.4185 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00008: val_loss did not improve from 0.82080
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.6427 - accuracy: 0.8275 - precision: 0.1651 - recall: 0.8976 - val_loss: 1.5250 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00009: val_loss did not improve from 0.82080
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.6598 - accuracy: 0.8200 - precision: 0.1538 - recall: 0.8712 - val_loss: 1.6103 - val_accuracy: 0.0404 - val_precision: 0.0404 - val_recall: 1.0000
#
# Epoch 00010: val_loss did not improve from 0.82080
# prediction target is wheat
#
#
# --------------------------------------------------
# load Model_eff0
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 65s - loss: 0.8612 - accuracy: 0.6279 - precision: 0.4489 - recall: 0.6220 - val_loss: 0.6068 - val_accuracy: 0.6613 - val_precision: 0.4871 - val_recall: 0.6000
#
# Epoch 00001: val_loss improved from inf to 0.60684, saving model to Model_eff0_wheat_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 6s - loss: 0.7561 - accuracy: 0.7103 - precision: 0.5480 - recall: 0.6916 - val_loss: 0.5599 - val_accuracy: 0.7136 - val_precision: 0.5703 - val_recall: 0.5176
#
# Epoch 00002: val_loss improved from 0.60684 to 0.55989, saving model to Model_eff0_wheat_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 7s - loss: 0.6800 - accuracy: 0.7508 - precision: 0.5967 - recall: 0.7486 - val_loss: 0.5848 - val_accuracy: 0.6863 - val_precision: 0.5172 - val_recall: 0.6679
#
# Epoch 00003: val_loss did not improve from 0.55989
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 6s - loss: 0.6125 - accuracy: 0.7824 - precision: 0.6356 - recall: 0.7891 - val_loss: 0.5602 - val_accuracy: 0.7130 - val_precision: 0.5603 - val_recall: 0.5846
#
# ...
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 11s - loss: 1.0560 - accuracy: 0.6415 - precision: 0.0606 - recall: 0.7882 - val_loss: 0.1499 - val_accuracy: 0.9632 - val_precision: 0.2250 - val_recall: 0.0882
#
# Epoch 00002: val_loss improved from 0.32422 to 0.14990, saving model to Model_ICPV2_fish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 11s - loss: 0.8587 - accuracy: 0.7644 - precision: 0.0927 - recall: 0.8217 - val_loss: 0.2772 - val_accuracy: 0.9676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.14990
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 11s - loss: 0.7149 - accuracy: 0.8063 - precision: 0.1212 - recall: 0.8851 - val_loss: 0.4487 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.14990
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 11s - loss: 0.6254 - accuracy: 0.8473 - precision: 0.1523 - recall: 0.9057 - val_loss: 0.3299 - val_accuracy: 0.9263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.14990
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.4801 - accuracy: 0.9054 - precision: 0.2272 - recall: 0.9027 - val_loss: 0.2539 - val_accuracy: 0.9302 - val_precision: 0.0350 - val_recall: 0.0490
#
# Epoch 00006: val_loss did not improve from 0.14990
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.4770 - accuracy: 0.9035 - precision: 0.2180 - recall: 0.9193 - val_loss: 0.2541 - val_accuracy: 0.9091 - val_precision: 0.0603 - val_recall: 0.1373
#
# Epoch 00007: val_loss did not improve from 0.14990
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.4879 - accuracy: 0.9042 - precision: 0.2283 - recall: 0.9013 - val_loss: 0.2749 - val_accuracy: 0.8907 - val_precision: 0.0682 - val_recall: 0.2059
#
# Epoch 00008: val_loss did not improve from 0.14990
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.4301 - accuracy: 0.9022 - precision: 0.2116 - recall: 0.9209 - val_loss: 0.2999 - val_accuracy: 0.8728 - val_precision: 0.0755 - val_recall: 0.2843
#
# Epoch 00009: val_loss did not improve from 0.14990
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 12s - loss: 0.4650 - accuracy: 0.9049 - precision: 0.2249 - recall: 0.9244 - val_loss: 0.3200 - val_accuracy: 0.8592 - val_precision: 0.0792 - val_recall: 0.3431
#
# Epoch 00010: val_loss did not improve from 0.14990
# prediction target is fish
#
#
# --------------------------------------------------
# load Model_ICPV3
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 95s - loss: 1.4154 - accuracy: 0.5301 - precision: 0.0422 - recall: 0.6558 - val_loss: 0.2732 - val_accuracy: 0.9655 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.27319, saving model to Model_ICPV3_fish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 7s - loss: 1.1096 - accuracy: 0.6442 - precision: 0.0564 - recall: 0.7455 - val_loss: 0.2117 - val_accuracy: 0.9649 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.27319 to 0.21171, saving model to Model_ICPV3_fish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 7s - loss: 0.9608 - accuracy: 0.7149 - precision: 0.0748 - recall: 0.7785 - val_loss: 0.2675 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.21171
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 7s - loss: 0.8355 - accuracy: 0.7577 - precision: 0.0923 - recall: 0.8282 - val_loss: 0.2302 - val_accuracy: 0.9611 - val_precision: 0.0606 - val_recall: 0.0196
#
# Epoch 00004: val_loss did not improve from 0.21171
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 8s - loss: 0.7201 - accuracy: 0.8221 - precision: 0.1339 - recall: 0.8645 - val_loss: 0.2266 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.21171
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.6005 - accuracy: 0.8161 - precision: 0.1233 - recall: 0.8944 - val_loss: 0.1694 - val_accuracy: 0.9670 - val_precision: 0.2000 - val_recall: 0.0294
#
# Epoch 00006: val_loss improved from 0.21171 to 0.16938, saving model to Model_ICPV3_fish_9527.h5
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5970 - accuracy: 0.8174 - precision: 0.1288 - recall: 0.9172 - val_loss: 0.1793 - val_accuracy: 0.9477 - val_precision: 0.1373 - val_recall: 0.1373
#
# Epoch 00007: val_loss did not improve from 0.16938
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5880 - accuracy: 0.8178 - precision: 0.1279 - recall: 0.9132 - val_loss: 0.2283 - val_accuracy: 0.9162 - val_precision: 0.0872 - val_recall: 0.1863
#
# Epoch 00008: val_loss did not improve from 0.16938
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.5912 - accuracy: 0.8226 - precision: 0.1311 - recall: 0.9038 - val_loss: 0.2826 - val_accuracy: 0.8797 - val_precision: 0.0732 - val_recall: 0.2549
#
# Epoch 00009: val_loss did not improve from 0.16938
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.5923 - accuracy: 0.8239 - precision: 0.1405 - recall: 0.9311 - val_loss: 0.3287 - val_accuracy: 0.8491 - val_precision: 0.0735 - val_recall: 0.3431
#
# Epoch 00010: val_loss did not improve from 0.16938
# prediction target is fish
#
#
# --------------------------------------------------
# load Model_XCP
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 64s - loss: 1.3258 - accuracy: 0.6139 - precision: 0.0439 - recall: 0.5700 - val_loss: 0.4895 - val_accuracy: 0.7968 - val_precision: 0.0843 - val_recall: 0.5784
#
# Epoch 00001: val_loss improved from inf to 0.48952, saving model to Model_XCP_fish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 8s - loss: 1.0374 - accuracy: 0.6921 - precision: 0.0685 - recall: 0.7674 - val_loss: 0.1389 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.48952 to 0.13889, saving model to Model_XCP_fish_9527.h5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 8s - loss: 0.8241 - accuracy: 0.7633 - precision: 0.1000 - recall: 0.8629 - val_loss: 0.2084 - val_accuracy: 0.9691 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss did not improve from 0.13889
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 8s - loss: 0.6269 - accuracy: 0.8325 - precision: 0.1356 - recall: 0.8832 - val_loss: 0.2373 - val_accuracy: 0.9682 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00004: val_loss did not improve from 0.13889
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 8s - loss: 0.4874 - accuracy: 0.8826 - precision: 0.1852 - recall: 0.9158 - val_loss: 0.2616 - val_accuracy: 0.9685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 0.13889
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3195 - accuracy: 0.9275 - precision: 0.2904 - recall: 0.9572 - val_loss: 0.1927 - val_accuracy: 0.9661 - val_precision: 0.2000 - val_recall: 0.0392
#
# Epoch 00006: val_loss did not improve from 0.13889
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.2872 - accuracy: 0.9272 - precision: 0.2788 - recall: 0.9550 - val_loss: 0.1713 - val_accuracy: 0.9531 - val_precision: 0.0625 - val_recall: 0.0392
#
# Epoch 00007: val_loss did not improve from 0.13889
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3446 - accuracy: 0.9263 - precision: 0.2678 - recall: 0.9393 - val_loss: 0.1812 - val_accuracy: 0.9430 - val_precision: 0.1429 - val_recall: 0.1765
#
# Epoch 00008: val_loss did not improve from 0.13889
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3262 - accuracy: 0.9278 - precision: 0.2834 - recall: 0.9392 - val_loss: 0.1997 - val_accuracy: 0.9299 - val_precision: 0.1398 - val_recall: 0.2549
#
# Epoch 00009: val_loss did not improve from 0.13889
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.3118 - accuracy: 0.9257 - precision: 0.2774 - recall: 0.9392 - val_loss: 0.2194 - val_accuracy: 0.9207 - val_precision: 0.1397 - val_recall: 0.3137
#
# Epoch 00010: val_loss did not improve from 0.13889
# prediction target is fish
#
#
# --------------------------------------------------
# load Model_RN50
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 69s - loss: 1.5543 - accuracy: 0.5468 - precision: 0.0382 - recall: 0.5912 - val_loss: 2.2667 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 2.26672, saving model to Model_RN50_fish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 8s - loss: 1.3116 - accuracy: 0.6281 - precision: 0.0589 - recall: 0.7677 - val_loss: 14.1945 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 2.26672
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 7s - loss: 1.1393 - accuracy: 0.6874 - precision: 0.0648 - recall: 0.7301 - val_loss: 0.5307 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00003: val_loss improved from 2.26672 to 0.53067, saving model to Model_RN50_fish_9527.h5
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 8s - loss: 0.8802 - accuracy: 0.7660 - precision: 0.0954 - recall: 0.8282 - val_loss: 1.3249 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00004: val_loss did not improve from 0.53067
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 7s - loss: 0.7844 - accuracy: 0.7899 - precision: 0.1078 - recall: 0.8435 - val_loss: 0.9152 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00005: val_loss did not improve from 0.53067
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.6280 - accuracy: 0.8584 - precision: 0.1576 - recall: 0.8962 - val_loss: 0.9563 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00006: val_loss did not improve from 0.53067
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.6124 - accuracy: 0.8624 - precision: 0.1636 - recall: 0.9007 - val_loss: 0.9779 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00007: val_loss did not improve from 0.53067
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.6010 - accuracy: 0.8613 - precision: 0.1656 - recall: 0.8997 - val_loss: 0.9982 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00008: val_loss did not improve from 0.53067
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 8s - loss: 0.6528 - accuracy: 0.8602 - precision: 0.1609 - recall: 0.8667 - val_loss: 1.0229 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00009: val_loss did not improve from 0.53067
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 7s - loss: 0.6138 - accuracy: 0.8616 - precision: 0.1648 - recall: 0.9178 - val_loss: 1.0534 - val_accuracy: 0.0306 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00010: val_loss did not improve from 0.53067
# prediction target is fish
#
#
# --------------------------------------------------
# load Model_RN101
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.000256.
# 39/39 - 115s - loss: 1.5944 - accuracy: 0.5831 - precision: 0.0425 - recall: 0.6383 - val_loss: 1.0500 - val_accuracy: 0.9697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 1.04996, saving model to Model_RN101_fish_9527.h5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00025499999999999996.
# 39/39 - 10s - loss: 1.4550 - accuracy: 0.5848 - precision: 0.0509 - recall: 0.7243 - val_loss: 1346.6810 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00002: val_loss did not improve from 1.04996
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000254.
# 39/39 - 10s - loss: 1.2701 - accuracy: 0.6474 - precision: 0.0603 - recall: 0.7391 - val_loss: 5.3683 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00003: val_loss did not improve from 1.04996
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00025299999999999997.
# 39/39 - 10s - loss: 1.0649 - accuracy: 0.7015 - precision: 0.0696 - recall: 0.7622 - val_loss: 1.0879 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00004: val_loss did not improve from 1.04996
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000252.
# 39/39 - 10s - loss: 0.9101 - accuracy: 0.7450 - precision: 0.0852 - recall: 0.8056 - val_loss: 0.8732 - val_accuracy: 0.0330 - val_precision: 0.0304 - val_recall: 1.0000
#
# Epoch 00005: val_loss improved from 1.04996 to 0.87323, saving model to Model_RN101_fish_9527.h5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.8248 - accuracy: 0.7909 - precision: 0.1099 - recall: 0.8400 - val_loss: 1.5919 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00006: val_loss did not improve from 0.87323
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.8030 - accuracy: 0.7871 - precision: 0.1097 - recall: 0.8393 - val_loss: 2.0225 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00007: val_loss did not improve from 0.87323
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.7735 - accuracy: 0.7912 - precision: 0.1085 - recall: 0.8646 - val_loss: 2.2025 - val_accuracy: 0.0303 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00008: val_loss did not improve from 0.87323
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 10s - loss: 0.7913 - accuracy: 0.7919 - precision: 0.1080 - recall: 0.8636 - val_loss: 2.1620 - val_accuracy: 0.0309 - val_precision: 0.0303 - val_recall: 1.0000
#
# Epoch 00009: val_loss did not improve from 0.87323
# Epoch 10/10
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 1e-07.
# 39/39 - 11s - loss: 0.7789 - accuracy: 0.7956 - precision: 0.1181 - recall: 0.8730 - val_loss: 1.9802 - val_accuracy: 0.0333 - val_precision: 0.0301 - val_recall: 0.9902
#
# Epoch 00010: val_loss did not improve from 0.87323
