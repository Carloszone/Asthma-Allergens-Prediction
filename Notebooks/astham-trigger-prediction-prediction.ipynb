# %%
# !pip install -q efficientnet

import os
import numpy as np 
import pandas as pd
import random
import math

import warnings
from shutil import copyfile
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.applications as tfka
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image
import tensorflow_hub as hub
import tensorflow_datasets as tfds
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import efficientnet.tfkeras as efn
from tqdm import tqdm
import gc
import cv2
from tensorflow.keras import backend as K

# %%
# Configuration
# For tf.dataset
AUTO = tf.data.experimental.AUTOTUNE

EPOCHS = 10
BATCH_SIZE = 32
IMAGE_SIZE = [256, 256]
# Seed
SEED = 9527
seed = 9527
# Learning rate
LR = 0.0005
# Verbosity
VERBOSE = 2
# Label_dim
label_dim = 1
N_CLASSES = 2

# dataset path
img_path = '../input/food-ingredients-and-recipe-dataset-with-images/Food Images/Food Images/'


common_allergens = {
    'cows milk': {'Cheese', 'Butter', 'Margarine', 'Yogurt', 'Cream', 'Ice cream'},
    'eggs': {'egg'},
    'tree nuts': {'Brazil nut', 'Almond', 'Cashew', 'Macadamia nut', 'Pistachio','Pine nut','Walnut'},
    'peanuts': {'peanut'},
    'shellfish': {'Shrimp','Prawn','Crayfish', 'Lobster', 'Squid', 'Scallops'},
    'wheat': {'flour', 'wheat', 'pasta', 'noodle', 'bread', 'crust'},
    'soy': {'soy', 'tofu', 'soya'},
    'fish': {'fish', 'seafood'}
}

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

def image_mapping_check(dataset):
    counter = 0
    record = []
    while counter < dataset.shape[0]-1:
        row = dataset.loc[counter]
        img_name = row['Image_Name']
        img = cv2.imread(img_path+img_name+'.jpg')
        try:
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR) 
        except:
            record.append(counter)
        counter+= 1
    new = dataset.drop(record, axis = 0)
    new = new.reset_index(drop = True)
    return new

def allergens_mapping(row, types):
    for item in common_allergens[types]:
        if item.lower() in row.lower():
                return 1
    return 0

def combination(row):
    return(row['cows_milk'], row['eggs'], row['tree nuts'], row['peanuts'], row['shellfish'], row['wheat'], row['soy'], row['fish'])


def load_dataset():
    path = "../input/food-ingredients-and-recipe-dataset-with-images/Food Ingredients and Recipe Dataset with Image Name Mapping.csv"
    df = pd.read_csv(path)
    df = image_mapping_check(df)
    df['image_path'] = img_path + df['Image_Name'] + '.jpg'
    df['cows_milk'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'cows milk'))
    df['eggs'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'eggs'))
    df['tree nuts'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'tree nuts'))
    df['peanuts'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'peanuts'))
    df['shellfish'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'shellfish'))
    df['wheat'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'wheat'))
    df['soy'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'soy'))
    df['fish'] = df['Cleaned_Ingredients'].apply(lambda x: allergens_mapping(x, types = 'fish'))
    df['total'] = df.apply(combination, axis = 1)
    x_train, x_val, y_train, y_val = train_test_split(df[['image_path']], df.iloc[:,7:16], shuffle = True, random_state = seed, test_size = 0.25)
    train_df = pd.concat([x_train, y_train], axis = 1).reset_index(drop = True)
    val_df = pd.concat([x_val, y_val], axis = 1).reset_index(drop = True)
    train_df.head()
    return df, train_df, val_df

# Function to decode our images
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels = 3)
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.cast(image, tf.float32) / 255.0
    return image

# Function to read our test image and return image
def read_image(image):
    image = tf.io.read_file(image)
    image = decode_image(image)
    return image

# Function to get our dataset that read images
def get_dataset(image):
    dataset = tf.data.Dataset.from_tensor_slices(image)
    dataset = dataset.map(read_image, num_parallel_calls = AUTO)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

# %%
# Arcmarginproduct class keras layer
class ArcMarginProduct(tf.keras.layers.Layer):
    '''
    Implements large margin arc distance.

    Reference:
        https://arxiv.org/pdf/1801.07698.pdf
        https://github.com/lyakaap/Landmark2019-1st-and-3rd-Place-Solution/
            blob/master/src/modeling/metric_learning.py
    '''
    def __init__(self, n_classes, s=30, m=0.50, easy_margin=False,
                 ls_eps=0.0, **kwargs):

        super(ArcMarginProduct, self).__init__(**kwargs)

        self.n_classes = n_classes
        self.s = s
        self.m = m
        self.ls_eps = ls_eps
        self.easy_margin = easy_margin
        self.cos_m = tf.math.cos(m)
        self.sin_m = tf.math.sin(m)
        self.th = tf.math.cos(math.pi - m)
        self.mm = tf.math.sin(math.pi - m) * m

    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'n_classes': self.n_classes,
            's': self.s,
            'm': self.m,
            'ls_eps': self.ls_eps,
            'easy_margin': self.easy_margin,
        })
        return config

    def build(self, input_shape):
        super(ArcMarginProduct, self).build(input_shape[0])

        self.W = self.add_weight(
            name='W',
            shape=(int(input_shape[0][-1]), self.n_classes),
            initializer='glorot_uniform',
            dtype='float32',
            trainable=True,
            regularizer=None)

    def call(self, inputs):
        X, y = inputs
        y = tf.cast(y, dtype=tf.int32)
        cosine = tf.matmul(
            tf.math.l2_normalize(X, axis=1),
            tf.math.l2_normalize(self.W, axis=0)
        )
        sine = tf.math.sqrt(1.0 - tf.math.pow(cosine, 2))
        phi = cosine * self.cos_m - sine * self.sin_m
        if self.easy_margin:
            phi = tf.where(cosine > 0, phi, cosine)
        else:
            phi = tf.where(cosine > self.th, phi, cosine - self.mm)
        one_hot = tf.cast(
            tf.one_hot(y, depth=self.n_classes),
            dtype=cosine.dtype
        )
        if self.ls_eps > 0:
            one_hot = (1 - self.ls_eps) * one_hot + self.ls_eps / self.n_classes

        output = (one_hot * phi) + ((1.0 - one_hot) * cosine)
        output *= self.s
        return output

# %%
# Function for a custom learning rate scheduler with warmup and decay
def get_lr_callback():
    # lr_start   = 0.0000001
    # lr_max     = 0.000005 * BATCH_SIZE
    lr_min     = 0.0000001
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
    def lrfn(epoch):
        if epoch < EPOCHS/2:
            lr = 0.00001 * (BATCH_SIZE - epoch)
        #elif epoch < EPOCHS/3 * 2:
        #    lr = 0.000001 * (BATCH_SIZE - epoch)
        else:
            lr = lr_min
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = True)
    return lr_callback

# %%
def get_model(mode):
    
    inp = tf.keras.layers.Input(shape = (*IMAGE_SIZE, 3), name = 'inp')
    if mode == 'eff0':
        x = efn.EfficientNetB0(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff1':
        x = efn.EfficientNetB1(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff2':
        x = efn.EfficientNetB2(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff3':
        x = efn.EfficientNetB3(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff4':
        x = efn.EfficientNetB4(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff5':
        x = efn.EfficientNetB5(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff6':
        x = efn.EfficientNetB6(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'eff7':
        x = efn.EfficientNetB7(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'ICPV2':
        x = tfka.InceptionResNetV2(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'ICPV3':
        x = tfka.InceptionV3(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'XCP':
        x = tfka.Xception(weights = 'imagenet', include_top = False)(inp)
    elif mode == 'RN50':
        x = tfka.ResNet50(weights = 'imagenet', include_top = False)(inp)
    else:
        # 'RN101'
        x = tfka.ResNet101(weights = 'imagenet', include_top = False)(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    output = tf.keras.layers.Dense(label_dim, activation='sigmoid')(x)
    model = tf.keras.models.Model(inputs = [inp], outputs = [output])
    return model

def model_prediction(image_paths,target, mode):
    model = get_model(mode)
    weight_path = '../input/asthma-allenger-prediction-model-weights/'f'Model_{mode}_{target}_{SEED}.h5'
    print(weight_path)
    model.load_weights(weight_path)   
    img = get_dataset(image_paths)
    pred = model.predict(img)
    return pred

# %%
def get_report(targets, models, thresholds):
    seed_everything(seed)
    df, train_df, val_df = load_dataset()
    final_target = []
    final_model = []
    final_acc = []
    final_acc_threshold = []
    final_f1s = []
    final_f1s_threshold = []
    for target in targets:
        for mode in models:
            acc = []
            f1s = []
            pred = model_prediction(val_df.image_path.values,target = target, mode = mode)
            y_true = val_df[target].values
            for threshold in thresholds:
                y_pred = np.array([1 if x > threshold else 0 for x in pred])
                accuracy = accuracy_score(y_true,y_pred)
                f1s_score = f1_score(y_true, y_pred, pos_label = 0)
                acc.append(accuracy)
                f1s.append(f1s_score)
            best_acc = max(acc)
            best_acc_threshold = thresholds[acc.index(best_acc)]
            best_f1s = max(f1s)
            best_f1s_threshold = thresholds[f1s.index(best_f1s)]

            print('\n')
            print(f'Allenger: {target}, Model: {mode}')
            print(f'Our best accuracy is {best_acc} with threshold {best_acc_threshold}')
            print(f'Our best f1 score is {best_f1s} with threshold {best_f1s_threshold}')
            final_target.append(target)
            final_model.append(mode)
            final_acc.append(best_acc)
            final_acc_threshold.append(best_acc_threshold)
            final_f1s.append(best_f1s)
            final_f1s_threshold.append(best_f1s_threshold)
    result = pd.DataFrame({
        'Allergens': final_target,
        'Model': final_model,
        'Accuracy': final_acc,
        'Accuracy_threshold': final_acc_threshold,
        'F1_score': final_f1s,
        'F1_score_threshold': final_f1s_threshold
    })

    return result

# %%
models = ['eff0','eff1','eff2','eff3','eff4','eff5','eff6','eff7','ICPV2','ICPV3', 'XCP', 'RN50', 'RN101']
targets = ["cows_milk", "eggs", "tree nuts", "peanuts", "shellfish", "wheat", "soy", "fish"]
thresholds = list(np.arange(0, 0.8, 0.01))

# %%
result = get_report(targets = targets, models = models, thresholds = thresholds)
result.to_csv('Single_model_results.csv', index = False)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff0
# Our best accuracy is 0.6550802139037433 with threshold 0.58
# Our best f1 score is 0.6991907514450867 with threshold 0.71
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b1_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 27164672/27164032 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff1
# Our best accuracy is 0.6541889483065954 with threshold 0.52
# Our best f1 score is 0.6958493989566796 with threshold 0.6900000000000001
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b2_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 31940608/31936256 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff2
# Our best accuracy is 0.6571598336304219 with threshold 0.44
# Our best f1 score is 0.7049952874646561 with threshold 0.64
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b3_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 44113920/44107200 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff3
# Our best accuracy is 0.6708259061200238 with threshold 0.43
# Our best f1 score is 0.7104564114948081 with threshold 0.62
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b4_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 71892992/71892840 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff4
# Our best accuracy is 0.6482471776589424 with threshold 0.45
# Our best f1 score is 0.6959261760072023 with threshold 0.64
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b5_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 115515392/115515256 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff5
# Our best accuracy is 0.6586452762923352 with threshold 0.47000000000000003
# Our best f1 score is 0.7080103359173128 with threshold 0.58
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b6_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 165527552/165527152 [==============================] - 2s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff6
# Our best accuracy is 0.6616161616161617 with threshold 0.45
# Our best f1 score is 0.7011140080587817 with threshold 0.5700000000000001
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b7_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 258441216/258434480 [==============================] - 3s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: eff7
# Our best accuracy is 0.6610219845513963 with threshold 0.38
# Our best f1 score is 0.705002337540907 with threshold 0.62
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: ICPV2
# Our best accuracy is 0.6298276886512181 with threshold 0.27
# Our best f1 score is 0.6828932261768083 with threshold 0.7000000000000001
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: ICPV3
# Our best accuracy is 0.6313131313131313 with threshold 0.56
# Our best f1 score is 0.6857400315386348 with threshold 0.78
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: XCP
# Our best accuracy is 0.6726084373143196 with threshold 0.67
# Our best f1 score is 0.7116049382716049 with threshold 0.77
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: RN50
# Our best accuracy is 0.5187165775401069 with threshold 0.53
# Our best f1 score is 0.6634882796980532 with threshold 0.65
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171450368/171446536 [==============================] - 1s 0us/step
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_cows_milk_9527.h5
#
#
# Allenger: cows_milk, Model: RN101
# Our best accuracy is 0.5065359477124183 with threshold 0.44
# Our best f1 score is 0.6632247815726767 with threshold 0.48
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff0
# Our best accuracy is 0.7462863933452168 with threshold 0.72
# Our best f1 score is 0.8447003779017456 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff1
# Our best accuracy is 0.7388591800356507 with threshold 0.75
# Our best f1 score is 0.8419917310803524 with threshold 0.75
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff2
# Our best accuracy is 0.7462863933452168 with threshold 0.59
# Our best f1 score is 0.843857427175683 with threshold 0.72
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff3
# Our best accuracy is 0.7498514557338086 with threshold 0.65
# Our best f1 score is 0.8449569833424859 with threshold 0.6900000000000001
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff4
# Our best accuracy is 0.750445632798574 with threshold 0.6900000000000001
# Our best f1 score is 0.8439033254588406 with threshold 0.76
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff5
# Our best accuracy is 0.7549019607843137 with threshold 0.71
# Our best f1 score is 0.8493800145878921 with threshold 0.72
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff6
# Our best accuracy is 0.7424242424242424 with threshold 0.54
# Our best f1 score is 0.8433179723502303 with threshold 0.72
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_eggs_9527.h5
#
#
# Allenger: eggs, Model: eff7
# Our best accuracy is 0.7492572786690433 with threshold 0.66
# Our best f1 score is 0.8454512239678481 with threshold 0.72
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_eggs_9527.h5
#
#
# Allenger: eggs, Model: ICPV2
# Our best accuracy is 0.7498514557338086 with threshold 0.65
# Our best f1 score is 0.8470034401593337 with threshold 0.7000000000000001
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_eggs_9527.h5
#
#
# Allenger: eggs, Model: ICPV3
# Our best accuracy is 0.7296494355317885 with threshold 0.61
# Our best f1 score is 0.8386197281282677 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_eggs_9527.h5
#
#
# Allenger: eggs, Model: XCP
# Our best accuracy is 0.7489601901366607 with threshold 0.71
# Our best f1 score is 0.8441464298658935 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_eggs_9527.h5
#
#
# Allenger: eggs, Model: RN50
# Our best accuracy is 0.7177658942364825 with threshold 0.37
# Our best f1 score is 0.835696990660671 with threshold 0.38
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_eggs_9527.h5
#
#
# Allenger: eggs, Model: RN101
# Our best accuracy is 0.7177658942364825 with threshold 0.58
# Our best f1 score is 0.835696990660671 with threshold 0.58
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff0
# Our best accuracy is 0.8918597742127153 with threshold 0.77
# Our best f1 score is 0.9428391959798995 with threshold 0.77
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff1
# Our best accuracy is 0.8832442067736186 with threshold 0.79
# Our best f1 score is 0.9376882828603139 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff2
# Our best accuracy is 0.8894830659536542 with threshold 0.79
# Our best f1 score is 0.9414173228346456 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff3
# Our best accuracy is 0.8856209150326797 with threshold 0.79
# Our best f1 score is 0.9390919158361019 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff4
# Our best accuracy is 0.8865121806298277 with threshold 0.79
# Our best f1 score is 0.939690558888538 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff5
# Our best accuracy is 0.8737373737373737 with threshold 0.79
# Our best f1 score is 0.9319673443252761 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff6
# Our best accuracy is 0.8897801544860369 with threshold 0.79
# Our best f1 score is 0.9415656008820287 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: eff7
# Our best accuracy is 0.8918597742127153 with threshold 0.79
# Our best f1 score is 0.9428032683846637 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: ICPV2
# Our best accuracy is 0.8784907902554961 with threshold 0.79
# Our best f1 score is 0.9351925209950881 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: ICPV3
# Our best accuracy is 0.8915626856803327 with threshold 0.78
# Our best f1 score is 0.9426731584733783 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: XCP
# Our best accuracy is 0.8862150920974451 with threshold 0.79
# Our best f1 score is 0.9395422257300711 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: RN50
# Our best accuracy is 0.8936423054070113 with threshold 0.33
# Our best f1 score is 0.9438343269532475 with threshold 0.33
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_tree nuts_9527.h5
#
#
# Allenger: tree nuts, Model: RN101
# Our best accuracy is 0.8936423054070113 with threshold 0.3
# Our best f1 score is 0.9438343269532475 with threshold 0.3
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff0
# Our best accuracy is 0.9637551990493167 with threshold 0.74
# Our best f1 score is 0.9815431164901665 with threshold 0.77
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff1
# Our best accuracy is 0.9604872251931076 with threshold 0.79
# Our best f1 score is 0.9798332069749811 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff2
# Our best accuracy is 0.9622697563874034 with threshold 0.79
# Our best f1 score is 0.9807663183401485 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff3
# Our best accuracy is 0.9598930481283422 with threshold 0.78
# Our best f1 score is 0.9795113067233268 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff4
# Our best accuracy is 0.9557338086749851 with threshold 0.79
# Our best f1 score is 0.9773315076829454 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff5
# Our best accuracy is 0.9578134284016637 with threshold 0.78
# Our best f1 score is 0.9784128914563697 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff6
# Our best accuracy is 0.9340463458110517 with threshold 0.79
# Our best f1 score is 0.9657618753855644 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: eff7
# Our best accuracy is 0.936423054070113 with threshold 0.79
# Our best f1 score is 0.9670465044656605 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: ICPV2
# Our best accuracy is 0.9610814022578729 with threshold 0.78
# Our best f1 score is 0.9801485073495984 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: ICPV3
# Our best accuracy is 0.9595959595959596 with threshold 0.78
# Our best f1 score is 0.9793751895662723 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: XCP
# Our best accuracy is 0.9640522875816994 with threshold 0.78
# Our best f1 score is 0.981680545041635 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: RN50
# Our best accuracy is 0.964349376114082 with threshold 0.78
# Our best f1 score is 0.9818511796733213 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_peanuts_9527.h5
#
#
# Allenger: peanuts, Model: RN101
# Our best accuracy is 0.964349376114082 with threshold 0.01
# Our best f1 score is 0.9818511796733213 with threshold 0.01
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff0
# Our best accuracy is 0.9575163398692811 with threshold 0.78
# Our best f1 score is 0.9782905723394566 with threshold 0.78
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff1
# Our best accuracy is 0.9575163398692811 with threshold 0.77
# Our best f1 score is 0.9782707795167906 with threshold 0.77
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff2
# Our best accuracy is 0.9587046939988116 with threshold 0.79
# Our best f1 score is 0.9788721690226477 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff3
# Our best accuracy is 0.9592988710635769 with threshold 0.75
# Our best f1 score is 0.9792266868840032 with threshold 0.75
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff4
# Our best accuracy is 0.9554367201426025 with threshold 0.79
# Our best f1 score is 0.9771897810218978 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff5
# Our best accuracy is 0.9587046939988116 with threshold 0.79
# Our best f1 score is 0.9789042343299438 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff6
# Our best accuracy is 0.9572192513368984 with threshold 0.79
# Our best f1 score is 0.978108847674065 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: eff7
# Our best accuracy is 0.9587046939988116 with threshold 0.79
# Our best f1 score is 0.978897829057234 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: ICPV2
# Our best accuracy is 0.9592988710635769 with threshold 0.75
# Our best f1 score is 0.9792266868840032 with threshold 0.75
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: ICPV3
# Our best accuracy is 0.9590017825311943 with threshold 0.61
# Our best f1 score is 0.9790655339805826 with threshold 0.61
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: XCP
# Our best accuracy is 0.9587046939988116 with threshold 0.77
# Our best f1 score is 0.9789042343299438 with threshold 0.77
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: RN50
# Our best accuracy is 0.9595959595959596 with threshold 0.13
# Our best f1 score is 0.979381443298969 with threshold 0.13
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_shellfish_9527.h5
#
#
# Allenger: shellfish, Model: RN101
# Our best accuracy is 0.9595959595959596 with threshold 0.62
# Our best f1 score is 0.979381443298969 with threshold 0.62
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff0
# Our best accuracy is 0.7046939988116458 with threshold 0.56
# Our best f1 score is 0.8112312654145324 with threshold 0.5700000000000001
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff1
# Our best accuracy is 0.7213309566250743 with threshold 0.5
# Our best f1 score is 0.8192236598890942 with threshold 0.65
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff2
# Our best accuracy is 0.7231134878193701 with threshold 0.5700000000000001
# Our best f1 score is 0.8173652694610778 with threshold 0.7000000000000001
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff3
# Our best accuracy is 0.7341057635175282 with threshold 0.64
# Our best f1 score is 0.8221029616378452 with threshold 0.64
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff4
# Our best accuracy is 0.7299465240641712 with threshold 0.54
# Our best f1 score is 0.8228415513545119 with threshold 0.5700000000000001
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff5
# Our best accuracy is 0.7284610814022578 with threshold 0.59
# Our best f1 score is 0.8218323586744638 with threshold 0.59
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff6
# Our best accuracy is 0.7073677956030897 with threshold 0.54
# Our best f1 score is 0.8130718954248366 with threshold 0.6
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_wheat_9527.h5
#
#
# Allenger: wheat, Model: eff7
# Our best accuracy is 0.7341057635175282 with threshold 0.55
# Our best f1 score is 0.8244834910214327 with threshold 0.61
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_wheat_9527.h5
#
#
# Allenger: wheat, Model: ICPV2
# Our best accuracy is 0.7165775401069518 with threshold 0.65
# Our best f1 score is 0.8173913043478261 with threshold 0.74
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_wheat_9527.h5
#
#
# Allenger: wheat, Model: ICPV3
# Our best accuracy is 0.6761734997029115 with threshold 0.75
# Our best f1 score is 0.8038156947444204 with threshold 0.75
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_wheat_9527.h5
#
#
# Allenger: wheat, Model: XCP
# Our best accuracy is 0.713903743315508 with threshold 0.36
# Our best f1 score is 0.8123711340206186 with threshold 0.61
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_wheat_9527.h5
#
#
# Allenger: wheat, Model: RN50
# Our best accuracy is 0.672311348781937 with threshold 0.4
# Our best f1 score is 0.8037715708948586 with threshold 0.4
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_wheat_9527.h5
#
#
# Allenger: wheat, Model: RN101
# Our best accuracy is 0.6717171717171717 with threshold 0.73
# Our best f1 score is 0.8036253776435045 with threshold 0.73
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_soy_9527.h5
#
#
# Allenger: soy, Model: eff0
# Our best accuracy is 0.9441473559120618 with threshold 0.79
# Our best f1 score is 0.9712626108223784 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_soy_9527.h5
#
#
# Allenger: soy, Model: eff1
# Our best accuracy is 0.9453357100415924 with threshold 0.78
# Our best f1 score is 0.9717877951548606 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_soy_9527.h5
#
#
# Allenger: soy, Model: eff2
# Our best accuracy is 0.9224598930481284 with threshold 0.79
# Our best f1 score is 0.9593900731289872 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_soy_9527.h5
#
#
# Allenger: soy, Model: eff3
# Our best accuracy is 0.9352346999405823 with threshold 0.79
# Our best f1 score is 0.9663995067817509 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_soy_9527.h5
#
#
# Allenger: soy, Model: eff4
# Our best accuracy is 0.9141414141414141 with threshold 0.79
# Our best f1 score is 0.9546950932748081 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_soy_9527.h5
#
#
# Allenger: soy, Model: eff5
# Our best accuracy is 0.9382055852644088 with threshold 0.79
# Our best f1 score is 0.9679309281529448 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_soy_9527.h5
#
#
# Allenger: soy, Model: eff6
# Our best accuracy is 0.9171122994652406 with threshold 0.79
# Our best f1 score is 0.9560837399653708 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_soy_9527.h5
#
#
# Allenger: soy, Model: eff7
# Our best accuracy is 0.9224598930481284 with threshold 0.79
# Our best f1 score is 0.9592378572544119 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_soy_9527.h5
#
#
# Allenger: soy, Model: ICPV2
# Our best accuracy is 0.9444444444444444 with threshold 0.76
# Our best f1 score is 0.9713760906168682 with threshold 0.77
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_soy_9527.h5
#
#
# Allenger: soy, Model: ICPV3
# Our best accuracy is 0.9462269756387404 with threshold 0.73
# Our best f1 score is 0.9723706304381011 with threshold 0.73
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_soy_9527.h5
#
#
# Allenger: soy, Model: XCP
# Our best accuracy is 0.9450386215092097 with threshold 0.79
# Our best f1 score is 0.9717341482047365 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_soy_9527.h5
#
#
# Allenger: soy, Model: RN50
# Our best accuracy is 0.9462269756387404 with threshold 0.02
# Our best f1 score is 0.9723706304381011 with threshold 0.02
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_soy_9527.h5
#
#
# Allenger: soy, Model: RN101
# Our best accuracy is 0.9462269756387404 with threshold 0.06
# Our best f1 score is 0.9723706304381011 with threshold 0.06
# ../input/asthma-allenger-prediction-model-weights/Model_eff0_fish_9527.h5
#
#
# Allenger: fish, Model: eff0
# Our best accuracy is 0.9682115270350564 with threshold 0.79
# Our best f1 score is 0.9838490566037736 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff1_fish_9527.h5
#
#
# Allenger: fish, Model: eff1
# Our best accuracy is 0.9688057040998217 with threshold 0.73
# Our best f1 score is 0.9841509433962263 with threshold 0.73
# ../input/asthma-allenger-prediction-model-weights/Model_eff2_fish_9527.h5
#
#
# Allenger: fish, Model: eff2
# Our best accuracy is 0.9581105169340464 with threshold 0.79
# Our best f1 score is 0.9785876993166287 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff3_fish_9527.h5
#
#
# Allenger: fish, Model: eff3
# Our best accuracy is 0.9616755793226381 with threshold 0.79
# Our best f1 score is 0.9804575064384183 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff4_fish_9527.h5
#
#
# Allenger: fish, Model: eff4
# Our best accuracy is 0.9587046939988116 with threshold 0.79
# Our best f1 score is 0.9788528830062375 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff5_fish_9527.h5
#
#
# Allenger: fish, Model: eff5
# Our best accuracy is 0.9598930481283422 with threshold 0.79
# Our best f1 score is 0.9794988610478359 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff6_fish_9527.h5
#
#
# Allenger: fish, Model: eff6
# Our best accuracy is 0.9432560903149139 with threshold 0.79
# Our best f1 score is 0.9707100138015642 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_eff7_fish_9527.h5
#
#
# Allenger: fish, Model: eff7
# Our best accuracy is 0.964349376114082 with threshold 0.78
# Our best f1 score is 0.9818511796733213 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV2_fish_9527.h5
#
#
# Allenger: fish, Model: ICPV2
# Our best accuracy is 0.9696969696969697 with threshold 0.66
# Our best f1 score is 0.9846107423053712 with threshold 0.73
# ../input/asthma-allenger-prediction-model-weights/Model_ICPV3_fish_9527.h5
#
#
# Allenger: fish, Model: ICPV3
# Our best accuracy is 0.9693998811645871 with threshold 0.79
# Our best f1 score is 0.9844622114949464 with threshold 0.79
# ../input/asthma-allenger-prediction-model-weights/Model_XCP_fish_9527.h5
#
#
# Allenger: fish, Model: XCP
# Our best accuracy is 0.9696969696969697 with threshold 0.34
# Our best f1 score is 0.9846153846153847 with threshold 0.34
# ../input/asthma-allenger-prediction-model-weights/Model_RN50_fish_9527.h5
#
#
# Allenger: fish, Model: RN50
# Our best accuracy is 0.9696969696969697 with threshold 0.45
# Our best f1 score is 0.9846153846153847 with threshold 0.45
# ../input/asthma-allenger-prediction-model-weights/Model_RN101_fish_9527.h5
#
#
# Allenger: fish, Model: RN101
# Our best accuracy is 0.9696969696969697 with threshold 0.74
# Our best f1 score is 0.9846153846153847 with threshold 0.74
